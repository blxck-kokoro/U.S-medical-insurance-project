# %% [markdown]
# # Koszty ubezpieczeń medycznych USA

# %% [markdown]
# W tym projekcie przyjrzymy się zestawowi danych pacjentów, których informacje zostały zebrane. Głównym celem jest obliczenie przewidywanych kosztów ubezpieczeń medycznych dla każdego pacjenta oraz skupienie się na analizie tych kosztów. Te dane ustanowią fundament naszej nowej bazy danych - zapisy medyczne, która ma być czysta, czytelna oraz możliwa do aktuaizowania, w przypadku jeśli takowe aktualizacje wystąpią. Na końcu będziemy analizować oraz sortować naszą własną bazę danych.

# %% [markdown]
# Na początku powinien zostać zimportowany moduł csv, ponieważ będziemy pracować na zestawie danych zebranych w pliku o rozszerzeniu csv.

# %%
import csv

# %% [markdown]
# Teraz, kiedy mam pełny dostęp do modułu csv, możemy czytać zestaw danych naszych pacjentów. Poszczególne informacje o naszych pacjentach będą dodawane do różnych list aby nadać naszemu kodu trochę czystości.

# %%
age_list = []
sex_list = []
bmi_list = []
children_list = []
smoker_list = []
region_list = []
charges_list = []

with open("insurance.csv", "r") as insurance_csv:

    insurance_csv_reader = csv.DictReader(insurance_csv)
    for insurance in insurance_csv_reader:

        age_list.append(insurance["age"])
        sex_list.append(insurance["sex"])
        bmi_list.append(insurance["bmi"])
        children_list.append(insurance["children"])
        smoker_list.append(insurance["smoker"])
        region_list.append(insurance["region"])
        charges_list.append(insurance["charges"])

# %% [markdown]
# Informacje o wszystkich naszych pacjentach zostały zebrane i przydzielone do poszczególnych list. To umożliwi nam obliczenie przewidywanego kosztu ubezpieczenia dla każdej jednostki. W tym celu będziemy przeprowadzać iterację przez każdą listę aby upewnić się że żaden element nie zostanie pominięty, a potem użyjemy schematu do obliczeń.

# %%
estimated_insurance_cost_list = []

for age, sex, bmi, children, smoker in zip(age_list, sex_list, bmi_list, children_list, smoker_list):
    if sex == "male":
        sex = 1
    else:
        sex = 0

    if smoker == "yes":
        smoker = 1
    else:
        smoker = 0

    estimated_cost = 250 * int(age )- 128 * int(sex) + 370 * float(bmi) + 425 * int(children) + 24000 * int(smoker) - 12500
    estimated_cost_rounded = round(estimated_cost, 2)
    estimated_insurance_cost_list.append(estimated_cost_rounded)

print(estimated_insurance_cost_list)
# Out:
# [26573.0, 4791.9, 7857.0, 4022.85, 6057.6, 4773.8, 11797.8, 8288.8, 8509.1, 12060.8, 3323.4, 36727.3, 5850.0, 16233.4, 33710.1, 1649.0, 12313.6, 1944.65, 16283.0, 31933.0, 15821.85, 7413.0, 4489.0, 32235.4, 7841.25, 13781.4, 11791.45, 14226.75, -20.55, 33403.0, 30044.0, 1736.55, 4957.0, 13596.7, 32265.0, -320.75, 16472.05, 1568.0, 34114.9, 41135.0, 3342.0, 9653.1, 6105.6, 8996.0, 11005.5, 14923.0, 7156.05, 7364.9, 11576.1, 33821.0, 5181.25, 6043.1, 34157.0, 33111.1, 9390.3, 40395.35, 14625.25, 28443.6, 33640.6, 10663.95, 9520.2, 7776.2, 12936.0, 4520.95, 24795.4, 2943.0, 18067.0, 7533.55, 10890.3, 28519.6, 27407.5, 7792.0, 12422.0, 14140.7, 9360.0, 14205.7, 6123.3, 5768.1, 7727.85, 9947.05, 5494.45, 12915.45, 31216.4, 16455.1, 34476.0, 31943.15, 37279.2, 11564.0, 9263.8, 11232.6, 7361.3, 10349.15, 38434.1, 9836.9, 39931.0, 8844.4, 13671.0, 15285.6, 32753.5, 28013.0, 9442.0, 4292.2, 3142.55, 39095.4, 6600.0, 27166.25, 3183.0, 6145.75, 4959.8, 40105.3, 13740.1, 13089.0, 8018.0, 5966.4, 13562.85, 12952.15, 20024.2, 29512.8, 9802.9, 6246.9, 12949.0, 659.5, 3220.75, 34396.5, 13073.55, 4650.45, 26721.0, 14338.0, 26923.05, 10561.0, 12056.85, 10904.8, 14883.0, 1577.35, 3150.45, 3378.5, 4739.0, 2186.75, 14078.0, 6320.0, 5017.4, 6318.3, 30083.0, 6473.95, 30762.3, 10392.1, 35430.15, 14635.1, 15024.1, 3055.0, 5475.1, 10361.0, 10518.65, 30646.9, 7345.2, 12994.4, 32407.4, 25186.75, 32018.1, 11572.1, 31842.0, 29634.5, 15949.0, 7376.0, 7588.8, 11261.55, 8315.0, 9042.35, 4450.25, 2391.85, 18465.9, 10833.0, -2222.8, 9551.0, 5837.65, 41199.0, 8020.95, 12101.0, 10543.0, 11292.35, 12452.15, 6163.6, 1528.5, 8271.7, 10577.3, 37148.15, 5920.4, 7708.0, 10089.0, 7480.7, 14302.9, 6194.0, 3145.8, 11767.0, 4611.1, 3440.3, 9386.0, 10182.0, 6928.5, 18052.1, 4130.7, 11850.1, 11392.95, 31599.6, 7123.0, 5610.6, 11890.0, 31235.8, 15016.0, 13052.1, 5007.0, 10495.75, 4767.0, 6315.1, 11033.0, 12327.0, 10592.0, 2669.0, 5495.4, 2087.7, 8894.0, 13052.5, 8043.0, 28998.0, 30988.8, 14932.6, 8454.2, 17506.7, 9879.95, 9392.2, 11817.15, 13822.1, -1164.0, 12722.0, 7040.7, 30571.4, 1890.1, 10176.3, 26877.9, 12879.2, 31667.9, 4364.95, 11591.0, 11708.0, 37513.8, 11979.4, 16582.2, 6640.2, 280.0, 5767.75, 23119.3, 40014.0, 38379.7, 6608.0, 35647.25, 11910.05, 37815.1, 11855.5, 10855.55, 27932.4, 11324.0, 26855.8, 34645.4, 29795.35, 16107.2, 39816.5, 29123.0, 15511.15, 10221.0, 9607.8, 3163.9, 37376.0, 12180.5, 10455.35, 3815.5, 9942.0, 599.55, 1991.0, 14734.3, 8652.2, 32329.4, 41156.05, 5525.65, 13661.15, 12044.0, 9146.4, 17635.9, 12951.4, 40278.05, 11415.0, 6858.0, 6013.8, 35321.8, 3663.4, 4813.0, 378.3, 26371.0, 32948.7, 33121.3, 10610.6, 7840.5, 34390.7, 16228.7, 7560.0, 16660.0, 7809.65, 5525.0, 7757.1, 14772.05, 10832.2, 9714.0, 1389.0, 36705.9, 12890.2, 29868.0, 12674.5, 11787.85, 12998.75, 8728.65, 9610.95, 5646.9, 6666.8, 31268.0, 16771.65, 4686.0, 10415.85, 3262.7, 36969.6, 40431.0, 13951.0, 40637.45, 34495.2, 14279.2, 12150.45, 12316.4, 16137.0, 11895.8, 13490.5, 36248.0, 9681.4, 3712.0, 13979.4, 12693.5, 16725.05, 16793.9, 8101.2, 9699.5, 11634.65, 7995.4, 2420.95, 10326.6, 9472.0, 5249.0, 8662.65, 6163.6, 9084.0, 16386.3, 11434.1, 8628.7, -307.7, 12301.0, 7832.0, 24279.0, 2943.0, 1699.3, 11563.6, 14726.0, 8094.45, 11067.55, 4395.0, 10553.3, 9975.1, 10692.35, 30895.0, 4704.1, 27724.7, 31734.3, 32227.5, 15917.55, 14937.2, 25743.35, 36475.45, 13332.0, 13135.8, 7411.95, 4850.0, 16448.5, 10107.05, 2365.7, 5952.7, 14253.25, 6099.1, 11431.65, 11646.5, 11801.0, 6218.35, 12253.0, 4099.4, 13694.0, 6122.9, 7872.0, 17129.4, 15697.05, 12848.0, 2670.0, 15550.6, 4744.7, 8407.0, 5961.4, 6908.1, -1410.4, 30411.95, 25212.15, 4590.0, 5255.5, 11861.8, 12989.0, 29712.0, 18286.2, 37232.6, 39907.6, 39890.2, 33923.75, 4940.3, 11396.0, 9741.7, 7513.05, 2791.05, -603.45, 6773.0, 4369.0, 3086.95, 7825.0, 13785.0, 6127.15, 15897.7, 4612.1, 8090.0, 19922.5, 4768.5, 7766.6, 32145.0, 7785.7, 16187.4, 35674.15, 10997.0, 13338.8, 10990.5, 8452.0, 10829.0, 9774.0, 4225.1, 2030.0, 3373.95, 13438.1, 15 ...

# %% [markdown]
# Na tym poziomie badania, jesteśmy zdolni do obliczenia średniego kosztu w naszych zapisach medycznych i dać naszym pacjentom cenne informacje o ich kosztach ubecpieczenia. W następnym kroku skupimy się na wyświetlaniu wiadomości dla naszych pacjentów, które będą informowały o tym, czy ich koszt ubezpieczenia jest ponad, czy poniżej średniej oraz co powinni zrobić aby obniżyć ich koszta, jeśli chcą.

# %%
total_cost = sum(estimated_insurance_cost_list)
costs_ammount = len(estimated_insurance_cost_list)
averge_estimated_insurance_cost = round(total_cost / costs_ammount, 2)

print(f"Średnia przewidywanych kosztów ubezpieczeń naszych zapisów medycznych jak dotąd: {averge_estimated_insurance_cost}$")
# Out:
# Średnia przewidywanych kosztów ubezpieczeń naszych zapisów medycznych jak dotąd: 13962.68$

# %%
for estimated_insurance_cost in estimated_insurance_cost_list:
    if estimated_insurance_cost < averge_estimated_insurance_cost:
        print(f"\nTwój przewidywany koszt ubezpieczenia: {estimated_insurance_cost}$.") 

        difference = round(averge_estimated_insurance_cost - estimated_insurance_cost, 2)
        print(f"To o {difference}$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.")

    elif estimated_insurance_cost == averge_estimated_insurance_cost:
        print(f"\nTwój przewidywany koszt ubezpieczenia: {estimated_insurance_cost}$.") 
        print("To równa się średniej wszystkich zebranych zapisów medycznych jak dotąd.")

    elif estimated_insurance_cost > averge_estimated_insurance_cost:
        print(f"\nTwój przewidywany koszt ubezpieczenia: {estimated_insurance_cost}$.") 

        difference = round(estimated_insurance_cost - averge_estimated_insurance_cost, 2)
        print(f"To o {difference}$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.")
# Out:
# ystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 15091.6$.
# To o 1128.92$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 32024.9$.
# To o 18062.22$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3610.0$.
# To o 10352.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 8226.75$.
# To o 5735.93$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6224.35$.
# To o 7738.33$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 14411.15$.
# To o 448.47$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 13032.75$.
# To o 929.93$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3299.35$.
# To o 10663.33$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3859.1$.
# To o 10103.58$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 27357.4$.
# To o 13394.72$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10035.5$.
# To o 3927.18$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 8658.35$.
# To o 5304.33$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5646.0$.
# To o 8316.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6470.4$.
# To o 7492.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 14660.75$.
# To o 698.07$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 4752.7$.
# To o 9209.98$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12498.0$.
# To o 1464.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 27368.6$.
# To o 13405.92$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3155.2$.
# To o 10807.48$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 15976.0$.
# To o 2013.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 33580.0$.
# To o 19617.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 30630.35$.
# To o 16667.67$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 16274.0$.
# To o 2311.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 8220.75$.
# To o 5741.93$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10589.0$.
# To o 3373.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: -184.1$.
# To o 14146.78$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 13671.0$.
# To o 291.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6239.35$.
# To o 7723.33$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6353.8$.
# To o 7608.88$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6651.6$.
# To o 7311.08$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9269.3$.
# To o 4693.38$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 36227.0$.
# To o 22264.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9452.7$.
# To o 4509.98$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3544.65$.
# To o 10418.03$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 7460.9$.
# To o 6501.78$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9233.0$.
# To o 4729.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 25535.4$.
# To o 11572.72$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6904.8$.
# To o 7057.88$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10908.4$.
# To o 3054.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3943.55$.
# To o 10019.13$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12478.6$.
# To o 1484.08$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 14111.1$.
# To o 148.42$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 13084.85$.
# To o 877.83$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 38406.45$.
# To o 24443.77$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 24566.0$.
# To o 10603.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 11378.85$.
# To o 2583.83$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10493.0$.
# To o 3469.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9897.1$.
# To o 4065.58$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5366.05$.
# To o 8596.63$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 11264.2$.
# To o 2698.48$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12439.55$.
# To o 1523.13$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6297.85$.
# To o 7664.83$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9763.1$.
# To o 4199.58$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 40688.0$.
# To o 26725.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 41897.2$.
# To o 27934.52$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 2148.6$.
# To o 11814.08$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6750.7$.
# To o 7211.98$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 4204.1$.
# To o 9758.58$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5488.0$.
# To o 8474.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9534.0$.
# To o 4428.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 8200.0$.
# To o 5762.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6733.4$.
# To o 7229.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 32240.1$.
# To o 18277.42$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 28409.1$.
# To o 14446.42$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: -552.0$.
# To o 14514.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 26473.0$.
# To o 12510.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10041.0$.
# To o 3921.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6256.4$.
# To o 7706.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12023.0$.
# To o 1939.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 14987.45$.
# To o 1024.77$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 11653.65$.
# To o 2309.03$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 16351.55$.
# To o 2388.87$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9076.6$.
# To o 4886.08$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3092.4$.
# To o 10870.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 8524.0$.
# To o 5438.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 8553.5$.
# To o 5409.18$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9738.0$.
# To o 4224.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12937.65$.
# To o 1025.03$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 36163.2$.
# To o 22200.52$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12535.0$.
# To o 1427.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 28866.05$.
# To o 14903.37$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 4821.0$.
# To o 9141.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10072.0$.
# To o 3890.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6845.55$.
# To o 7117.13$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6509.45$.
# To o 7453.23$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9689.4$.
# To o 4273.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6762.7$.
# To o 7199.98$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 27884.2$.
# To o 13921.52$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10391.0$.
# To o 3571.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 4248.0$.
# To o 9714.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6501.95$.
# To o 7460.73$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 32619.25$.
# To o 18656.57$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 4512.3$.
# To o 9450.38$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 11832.1$.
# To o 2130.58$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 34328.65$.
# To o 20365.97$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 24014.2$.
# To o 10051.52$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3408.1$.
# To o 10554.58$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 40478.0$.
# To o 26515.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 8248.4$.
# To o 5714.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 897.3$.
# To o 13065.38$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6508.0$.
# To o 7454.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 31800.0$.
# To o 17837.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 11495.4$.
# To o 2467.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5231.5$.
# To o 8731.18$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 29035.0$.
# To o 15072.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 1209.7$.
# To o 12752.98$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 9672.65$.
# To o 4290.03$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 11186.75$.
# To o 2775.93$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 937.0$.
# To o 13025.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 1538.25$.
# To o 12424.43$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5158.7$.
# To o 8803.98$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 6630.35$.
# To o 7332.33$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 2200.65$.
# To o 11762.03$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 33855.2$.
# To o 19892.52$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 39570.75$.
# To o 25608.07$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 1871.0$.
# To o 12091.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 32408.0$.
# To o 18445.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 31825.85$.
# To o 17863.17$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3756.4$.
# To o 10206.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 26834.5$.
# To o 12871.82$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 31476.4$.
# To o 17513.72$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 28924.0$.
# To o 14961.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10386.0$.
# To o 3576.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 8033.55$.
# To o 5929.13$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5627.15$.
# To o 8335.53$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12170.0$.
# To o 1792.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 29939.0$.
# To o 15976.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 29027.35$.
# To o 15064.67$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 2771.7$.
# To o 11190.98$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: -128.0$.
# To o 14090.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 11530.1$.
# To o 2432.58$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12514.7$.
# To o 1447.98$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 7836.55$.
# To o 6126.13$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 7891.05$.
# To o 6071.63$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 36749.15$.
# To o 22786.47$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 17239.1$.
# To o 3276.42$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 37786.9$.
# To o 23824.22$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5142.95$.
# To o 8819.73$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 15029.95$.
# To o 1067.27$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 10161.9$.
# To o 3800.78$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 11658.1$.
# To o 2304.58$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3063.25$.
# To o 10899.43$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 15504.0$.
# To o 1541.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12123.8$.
# To o 1838.88$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5608.0$.
# To o 8354.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 18314.0$.
# To o 4351.32$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 12605.9$.
# To o 1356.78$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 3810.4$.
# To o 10152.28$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 5634.5$.
# To o 8328.18$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 2296.0$.
# To o 11666.68$ poniżej średniej wszystkich zebranych zapisów medycznych jak dotąd.
#
# Twój przewidywany koszt ubezpieczenia: 37505.9$.
# To o 23543.22$ powyżej średniej wszystkich zebranych zapisów medycznych jak dotąd.

# %%
def analyze_bmi(bmi_value):
  if bmi_value > 30:
    return('Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.')
  elif bmi_value >= 25:
    return('Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.')
  elif bmi_value >= 18.5 and bmi_value < 25:
    return('Twoje BMI jest na zdrowym poziomie')
  elif bmi_value < 18.5:
    return('Twoje BMI jest na poziomie niedowagi. Podwyższenie twojego BMI nie pomoże w redukowaniu kosztu, lecz poprawi twoje zdrowie.')

def bmi_advice(bmi_value):
  if bmi_value > 25:
      bmi_reduction = bmi_value - 25
      return(f'BMI powinno zostać obniżone o {bmi_reduction} aby utrzymać je na zdrowym poziomie.')
  if bmi_value < 18.5:
      bmi_increase = 18.5 - bmi_value
      return(f'BMI powinno zostać podwyższone o {bmi_increase} aby utrzymać je na zdrowym poziomie.')
  if bmi_value < 25 and bmi_value > 18.5:
      return

import decimal

for bmi in bmi_list:
    bmi = decimal.Decimal(bmi)

    print(f"Analiza: {analyze_bmi(round(bmi, 2))}")
    print(f"Porada: {bmi_advice(round(bmi, 2))}")
    print("\n")
# Out:
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 2.90 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 8.77 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 8.00 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na zdrowym poziomie
# Porada: None
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 3.88 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 0.74 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 8.44 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 2.74 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 4.83 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 0.84 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 1.22 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 1.29 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 9.40 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 14.82 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 17.13 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na zdrowym poziomie
# Porada: None
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 5.78 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na zdrowym poziomie
# Porada: None
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 15.30 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 10.30 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 11.00 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 7.40 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 9.10 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 6.92 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 3.02 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie nadwagi. Aby obniżyć koszt, twoje BMI  powinno zostać obniżone.
# Porada: BMI powinno zostać obniżone o 2.72 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na zdrowym poziomie
# Porada: None
#
#
# Analiza: Twoje BMI jest na poziomie otyłości. Aby obniżyć koszt, twoje BMI powinno zostać znacząco obniżone.
# Porada: BMI powinno zostać obniżone o 7.78 aby utrzymać je na zdrowym poziomie.
#
#
# Analiza: Twoje BMI jest na poziomie niedowagi. Podwyższenie twojego BMI nie pomoże w redukowaniu kosztu, lecz poprawi twoje zdrowie.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e87429ed54e7> in <module>
#      25
#      26     print(f"Analiza: {analyze_bmi(round(bmi, 2))}")
# ---> 27     print(f"Porada: {bmi_advice(round(bmi, 2))}")
#      28     print("\n")
#
# <ipython-input-6-e87429ed54e7> in bmi_advice(bmi_value)
#      14       return(f'BMI powinno zostać obniżone o {bmi_reduction} aby utrzymać je na zdrowym poziomie.')
#      15   if bmi_value < 18.5:
# ---> 16       bmi_increase = 18.5 - bmi_value
#      17       return(f'BMI powinno zostać podwyższone o {bmi_increase} aby utrzymać je na zdrowym poziomie.')
#      18   if bmi_value < 25 and bmi_value > 18.5:
#
# TypeError: unsupported operand type(s) for -: 'float' and 'decimal.Decimal'

# %%
def analyze_smoker(smoker_status):
  if smoker_status == 1:
    return('Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.')
  else:
    return('Palenie nie jest dla Ciebie problemem.')

for smoker in smoker_list:
    if smoker == "yes":
        smoker = 1
    else:
        smoker = 0
    
    print(analyze_smoker(smoker))
    print("\n")
# Out:
# zucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Palenie nie jest dla Ciebie problemem.
#
#
# Aby zmniejszyć koszt, radzimy przemyśleć rzucenie palenia.

# %% [markdown]
# Udało się nam poszerzyć naszą bazę danych o wartościowe dane naszych pacjentów w zapisach medycznych. Teraz możemy przejść do kolejnego kroku i stworzyć możliwość aby budować indywidualne profile pacjentów, złożonych z ich własnych danych. Będziemy do tego używać klas pythona aby uczynić je jasnymi i prostymi tak, jak to tylko możliwe. Ponadto napiszemy kilka metod, które zapewnią możliwość aktualizowania danych dla naszych klientów.

# %%
class Patient:

    def __init__(self, first_name, last_name, age, sex, bmi, num_of_children, smoker, region, charges, estimated_insurance_cost):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age

        if sex == "male":
            sex = 1
        else:
            sex = 0

        self.sex = sex
        self.bmi = bmi
        self.num_of_children = num_of_children

        if smoker == "yes":
            smoker = 1
        else:
            smoker = 0

        self.smoker = smoker
        self.region = region 
        self.charges = charges 

        self.estimated_insurance_cost = estimated_insurance_cost

    def estimated_insurance_cost_calculation(self):
        estimated_cost = 250 * int(self.age)- 128 * int(self.sex) + 370 * float(self.bmi) + 425 * int(self.num_of_children) + 24000 * int(self.smoker) - 12500
        print(f"{self.first_name} {self.last_name}, twój przewidywany koszt ubezpieczenia wynosi {estimated_cost} dollarów.")

    
    def update_age(self, new_age):
        self.age = new_age
        print(f"{self.first_name} {self.last_name} ma teraz {new_age} lat.")
        self.estimated_insurance_cost_calculation()

    def update_num_children(self, new_num_children):
        self.num_of_children = new_num_children
        if new_num_children == 1:
            print(f"{self.first_name} {self.last_name} ma teraz {new_num_children} dziecko.")
        else:
            print(f"{self.first_name} {self.last_name} ma teraz {new_num_children} dzieci.")
        self.estimated_insurance_cost_calculation()

    def update_bmi(self, new_bmi):
        self.bmi = new_bmi
        print(f"{self.first_name} {self.last_name}, twoje nowe bmi wynosi {new_bmi}.")
        self.estimated_insurance_cost_calculation()

    def update_smoking_status(self, new_smoking_status):
        self.smoker = new_smoking_status
        if new_smoking_status == 0:
            print(f"{self.first_name} {self.last_name} nie jest już palaczem.")
        elif new_smoking_status == 1:
            print(f"{self.first_name} {self.last_name} jest od tąd palaczem.")
        self.estimated_insurance_cost_calculation()
  
    def patient_profile(self):
        patient_informations = {
        "Imię":self.first_name,
        "Nazwisko":self.last_name,
        "Wiek":self.age,
        "Płeć":self.sex,
        "BMI":self.bmi,
        "Liczba Dzieci":self.num_of_children,
        "Palacz":self.smoker,
        "Region":self.region,
        "Opłaty":self.charges,
        "Przewidywany koszt ubezpieczenia":self.estimated_insurance_cost
        }

        for patient_information_key, patient_information_value in patient_informations.items():
            print (f"{patient_information_key} : {patient_information_value}")



patient_0 = Patient(
    first_name = "Pacjent",
    last_name = "Zero",
    age = age_list[0], 
    sex = sex_list[0],
    bmi = bmi_list[0], 
    num_of_children = children_list[0],
    smoker = smoker_list[0],
    region = region_list[0],
    charges = charges_list[0],
    estimated_insurance_cost = estimated_insurance_cost_list[0]
    )

patient_0.patient_profile()
print("\n")

patient_0.update_age(20)
print("\n")
patient_0.update_bmi(28.0)
print("\n")
patient_0.update_num_children(1)
print("\n")
patient_0.update_smoking_status(0)
# Out:
# Imię : Pacjent
# Nazwisko : Zero
# Wiek : 19
# Płeć : 0
# BMI : 27.9
# Liczba Dzieci : 0
# Palacz : 1
# Region : southwest
# Opłaty : 16884.924
# Przewidywany koszt ubezpieczenia : 26573.0
#
#
# Pacjent Zero ma teraz 20 lat.
# Pacjent Zero, twój przewidywany koszt ubezpieczenia wynosi 26823.0 dollarów.
#
#
# Pacjent Zero, twoje nowe bmi wynosi 28.0.
# Pacjent Zero, twój przewidywany koszt ubezpieczenia wynosi 26860.0 dollarów.
#
#
# Pacjent Zero ma teraz 1 dziecko.
# Pacjent Zero, twój przewidywany koszt ubezpieczenia wynosi 27285.0 dollarów.
#
#
# Pacjent Zero nie jest już palaczem.
# Pacjent Zero, twój przewidywany koszt ubezpieczenia wynosi 3285.0 dollarów.

# %% [markdown]
# Ostatni punkt tego projektu zawierać będzie analizę naszej własnej bazy danych, stworzonej z danych naszych pacjentów.

# %% [markdown]
# # Analiza kosztów ubepieczeń

# %%
highest_estimated_insurance_cost = max(estimated_insurance_cost_list)
print(f"Najwyższy prezewidywany koszt ubezpieczenia w bazie danych: {highest_estimated_insurance_cost}$")

lowest_estimated_insurance_cost = min(estimated_insurance_cost_list)
print(f"Najniższy przewidywany koszt ubezpieczenia w bazie danych: {lowest_estimated_insurance_cost}$")

total_cost = sum(estimated_insurance_cost_list)
costs_ammount = len(estimated_insurance_cost_list)
averge_estimated_insurance_cost = round(total_cost / costs_ammount, 2)
print(f"Średnia kosztów ubezpieczenia w bazie danych: {averge_estimated_insurance_cost}$")
# Out:
# Najwyższy prezewidywany koszt ubezpieczenia w naszej bazie danych: 42541.7$
# Najniższy przewidywany koszt ubezpieczenia w naszej bazie danych: -2222.8$
# Średnia kosztów ubezpieczenia w naszej bazie danych: 13962.68$

# %% [markdown]
# # Analiza wieku

# %%
eldest_patient = max(age_list)
print(f"Najstarszy pacjent w bazie danych ma {eldest_patient} lat.")

youngest_patient = min(age_list)
print(f"Najmłodszy pacjent w bazie danych ma {youngest_patient} lat.")

total_age = 0
for age in age_list:
    total_age += int(age)

age_ammount = len(age_list)
averge_age = round(total_age / age_ammount, 0)
print(f"Średnia wieku pacjentów w bazie danych: {averge_age} lat.")
# Out:
# Najstarszy pacjent w bazie danych ma 64 lat.
# Najmłodszy pacjent w bazie danych ma 18 lat.
# Średnia wieku pacjentów w bazie danych: 39.0 lat.

# %% [markdown]
# # Analiza płci

# %%
males_ammount = 0
females_ammount = 0

for sex in sex_list:
    if sex == "male":
        males_ammount += 1
    elif sex == "female":
        females_ammount += 1

print(f"Ilość mężczyzn w bazie danych: {males_ammount}")
print(f"Ilość kobiet w bazie danych: {females_ammount}")
    
if males_ammount > females_ammount:
    difference = males_ammount - females_ammount
    print(f"W bazie danych jest o {difference} więcej mężczyzn niż kobiet.")
elif females_ammount > males_ammount:
    difference = females_ammount - males_ammount
    print(f"W bazie danych jest o {difference} więcej kobiet niż mężczyzn.")
elif males_ammount == females_ammount:
    print("Ilość mężczyzn oraz kobiet w bazie danych jest na równym poziomie")
# Out:
# Ilość mężczyzn w bazie danych: 676
# Ilość kobiet w bazie danych: 662
# W bazie danych jest o 14 więcej mężczyzn niż kobiet.

# %% [markdown]
# # Analiza BMI

# %%
highest_bmi = max(bmi_list)
lowest_bmi = min(bmi_list)

total_bmi = 0
for bmi in bmi_list:
    total_bmi += float(bmi)

bmi_ammount = len(bmi_list)

averge_bmi = round(total_bmi / bmi_ammount, 2)

print(f"The highest bmi in database: {highest_bmi}")
print(f"The lowest bmi in database: {lowest_bmi}")
print(f"Averge bmi in database: {averge_bmi}")
# Out:
# The highest bmi in database: 53.13
# The lowest bmi in database: 15.96
# Averge bmi in database: 30.66

# %% [markdown]
# # Analiza liczby dzieci

# %%
highest_children_ammount_per_parent = 0
lowest_children_ammount_per_parent = 0

for children in children_list:
    if int(children) > highest_children_ammount_per_parent:
        highest_children_ammount_per_parent = int(children)

    if int(children) < lowest_children_ammount_per_parent:
        lowest_children_ammount_per_parent = int(children)


total_children_ammount = 0

for children in children_list:
    total_children_ammount += int(children)



parents = len(children_list)
averge_children_ammount = round(total_children_ammount / parents, 0)

print(f"Najwyższa liczba dzieci przypadająca na rodzica: {highest_children_ammount_per_parent}")
print(f"Najniższa liczba dzieci przypadająca na rodzica: {lowest_children_ammount_per_parent}")
print(f"Średnia liczba dzieci przypadająca na rodzica: {averge_children_ammount}")
# Out:
# Najwyższa liczba dzieci przypadająca na rodzica: 5
# Najniższa liczba dzieci przypadająca na rodzica: 0
# Średnia liczba dzieci przypadająca na rodzica: 1.0

# %% [markdown]
# # Analiza liczby palaczy

# %%
smokers = 0
none_smokers = 0

for smoker in smoker_list:
    if smoker == "yes":
        smokers += 1
    elif smoker == "no":
        none_smokers += 1

print(f"Ilość osób palących w bazie danych: {smokers}")
print(f"Ilość osób niepalących w bazie danych: {none_smokers}")

if smokers > none_smokers:
    difference = smokers - none_smokers
    print(f"W bazie danych jest o {difference} więcej osób palących niż niepalących.")
elif none_smokers > smokers:
    difference = none_smokers - smokers
    print(f"W bazie danych jest o {difference} więcej osób nieplących niż palących.")
elif smokers == none_smokers:
    print(f"Ilość osób palących oraz nie palących jest na tym samym poziomie.")
# Out:
# Ilość osób palących w bazie danych: 274
# Ilość osób niepalących w bazie danych: 1064
# W bazie danych jest o 790 więcej osób nieplących niż palących

# %% [markdown]
# # Analiza regionu

# %%
region_names = set(region_list)

print(f"Lista regionów z których pochodzą nasi pacjenci:")
for region in region_names:
    print(f"-{region.title()}")
print("\n")

print(f"Liczba pacjentów z północnego zachodu: {region_list.count('northwest')}")
print(f"Liczba pacjentów z północnego wschodu: {region_list.count('northeast')}")
print(f"Liczba pacjentów z południowego zachodu: {region_list.count('southwest')}")
print(f"Liczba pacjentów z południowego wschodu: {region_list.count('southeast')}")
# Out:
# Lista regionów z których pochodzą nasi pacjenci:
# -Northwest
# -Southeast
# -Southwest
# -Northeast
#
#
# Liczba pacjentów z północnego zachodu: 325
# Liczba pacjentów z północnego wschodu: 324
# Liczba pacjentów z południowego zachodu: 325
# Liczba pacjentów z południowego wschodu: 364

# %% [markdown]
# # Analiza opłat

# %%
float_charges_list = []
for charge in charges_list:
    float_charges_list.append(float(charge))

highest_charges = round(max(float_charges_list), 2)
lowest_charges = round(min(float_charges_list), 2)

total_charges = 0
for charges in charges_list:
    total_charges += float(charges)
charges_ammount = len(charges_list)
averge_charges = round(total_charges / charges_ammount, 2)

print(f"Najwyższy zapis opłat w bazie danych: {highest_charges}$")
print(f"Najniższy zapis opłat w bazie danych: {lowest_charges}$")
print(f"Średnia opłat w bazie danych: {averge_charges}$")
# Out:
# Najwyższy zapis opłat w bazie danych: 63770.43$
# Najniższy zapis opłat w bazie danych: 1121.87$
# Średnia opłat w bazie danych: 13270.42$

# %% [markdown]
# ## Podczas tego projektu wyjaśniliśmy poniższe aspekty:
#
# ### 1. Zdobyliśmy niezbędne informacje o pacjentach z pliku insurance.csv: ✓
#         * wiek
#         * płeć
#         * bmi
#         * ilość dzieci
#         * status palenia
#         * region
#         * opłaty
#
# ### 2. Obliczyliśmy przewidywany koszt ubezpieczenia dla każdego z pacjentów ✓
#
# ### 3. Poddaliśmy analizie koszt ubezpieczenia pacjentów: ✓
#         * obliczyliśmy średni koszt ubezpieczenia wśród zapisów medycznych ✓
#         * wyświetliliśmy informacje która powiadamia pacjenta o wysokości jego kosztu ubezpieczenia, o tym czy jest on powyżej czy poniżej średniej oraz o ile ✓
#         * daliśmy poradę co dany pacjent powinien zrobić aby obniżyć ewentualny koszt ✓
#
# ### 4. Stworzyliśmy możliwość dla klientów aby mogli tworzyć swój własny profil pacjenta ✓
#
# ### 5. Stworzyliśmy możliwość wprowadzania aktualizacji do naszej bazy danych ✓
#
# ### 6. Poddaliśmy analizie naszą własną bazę danych ✓

# %% [markdown]
# # Dziękuję za uwagę, Jakub Weleziński
